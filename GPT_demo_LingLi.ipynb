# %%
# %%bash
# nvidia-smi
# Out:
# Mon Feb 20 22:26:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %%capture
# %%bash
pip install --upgrade pip
pip install git+https://github.com/deepset-ai/haystack.git#egg=farm-haystack[colab,faiss]

pip install -qU openai

# %%
import logging
logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
logging.getLogger("haystack").setLevel(logging.INFO)

# %%
##################
#Document Store ##
#FAISS is a library for efficient similarity search on a cluster of dense vectors. The FAISSDocumentStore uses a SQL(SQLite in-memory be default) database under-the-hood to store the document text and other meta data. The vector embeddings of the text are indexed on a FAISS Index that later is queried for searching answers. The default flavour of FAISSDocumentStore is "Flat" but can also be set to "HNSW" for faster search at the expense of some accuracy. Just set the faiss_index_factor_str argument in the constructor. For more info on which suits your use case: https://github.com/facebookresearch/faiss/wiki/Guidelines-to-choose-an-index
##################
from haystack.document_stores import FAISSDocumentStore
#document_store = FAISSDocumentStore(embedding_dim=128, faiss_index_factory_str="Flat")
document_store = FAISSDocumentStore(embedding_dim=768, faiss_index_factory_str="Flat", return_embedding=True)
# Out:
# INFO:haystack.telemetry:Haystack sends anonymous usage data to understand the actual usage and steer dev efforts towards features that are most meaningful to users. You can opt-out at anytime by calling disable_telemetry() or by manually setting the environment variable  HAYSTACK_TELEMETRY_ENABLED as described for different operating systems on the documentation page. More information at https://docs.haystack.deepset.ai/docs/telemetry

# %%
#######################################################
## Create a document store base on GOT text extracts ##
######################################################
from google.colab.output import eval_js
eval_js('google.colab.output.setIframeHeight("100")')

from haystack.nodes import PreProcessor
pre_processor = PreProcessor(
    clean_empty_lines=True,
    clean_whitespace=True,
    clean_header_footer=True,
    split_by="word",
    split_length=400,
    split_respect_sentence_boundary=True,
    split_overlap=0)

from haystack.utils import convert_files_to_docs, fetch_archive_from_http, clean_wiki_text
# Let's first get some files that we want to use
doc_dir = "data/GOT"
s3_url = "https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt12.zip"
fetch_archive_from_http(url=s3_url, output_dir=doc_dir)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# INFO:haystack.utils.import_utils:Fetching from https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt12.zip to 'data/GOT'
# True

# %%
eval_js('google.colab.output.setIframeHeight("100")')
# Convert files to dicts
docs = convert_files_to_docs(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)
docs = pre_processor.process(docs)

# Now, let's write the dicts containing documents to our DB.
document_store.write_documents(docs)

# %%
#eval_js('google.colab.output.setIframeHeight("100")')
# Convert files to dicts
docs = convert_files_to_docs(dir_path = "ling_txt", clean_func=clean_wiki_text, split_paragraphs=True)
docs = pre_processor.process(docs)

# Now, let's write the dicts containing documents to our DB.
document_store.write_documents(docs)
# Out:
# INFO:haystack.utils.preprocessing:Converting ling_txt/test2 Application Logging Standard Ling.txt
# Preprocessing:   0%|          | 0/1 [00:00<?, ?docs/s]
# Writing Documents:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# here is where the model will encode the docment into vector
# all doc in doc store will be update with embeding vecotr
# model is download and stored locally
eval_js('google.colab.output.setIframeHeight("100")')

from haystack.nodes import DensePassageRetriever
retriever = DensePassageRetriever(
    document_store=document_store,
    #query_embedding_model="vblagoje/dpr-question_encoder-single-lfqa-wiki",
    query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
    #passage_embedding_model="vblagoje/dpr-ctx_encoder-single-lfqa-wiki",
    passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
    use_gpu=True,
    embed_title=True,
)

document_store.update_embeddings(retriever)
# Out:
# INFO:haystack.modeling.utils:Using devices: CUDA:0 - Number of GPUs: 1
# INFO:haystack.modeling.model.language_model:Auto-detected model language: english
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.
# INFO:haystack.modeling.model.language_model:Auto-detected model language: english
# INFO:haystack.document_stores.faiss:Updating embeddings for 2657 docs...
# Updating Embedding:   0%|          | 0/2657 [00:00<?, ? docs/s]
# Create embeddings:   0%|          | 0/2672 [00:00<?, ? Docs/s]

# %%
## Reader/Generator
# the reader will use the context it's given and generate a answer
# the model will be downloaded locally

from haystack.nodes import Seq2SeqGenerator, RAGenerator
#generator = Seq2SeqGenerator(model_name_or_path="yjernite/bart_eli5")
generator = Seq2SeqGenerator(model_name_or_path="vblagoje/bart_lfqa", max_length=600)


# Initialize RAG Generator
ra_generator = RAGenerator(
    model_name_or_path="facebook/rag-token-nq",
    use_gpu=True,
    top_k=1,
    max_length=600,
    min_length=2,
    embed_title=True,
    num_beams=2,
)
# Out:
# INFO:haystack.modeling.utils:Using devices: CUDA:0 - Number of GPUs: 1
# Downloading (…)okenizer_config.json:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# INFO:haystack.modeling.utils:Using devices: CUDA:0 - Number of GPUs: 1
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/models/bart/configuration_bart.py:179: UserWarning: Please make sure the config includes `forced_bos_token_id=0` in future versions. The config can simply be saved and uploaded again to be fixed.
#   warnings.warn(
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)_tokenizer/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/2.06G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/rag-token-nq were not used when initializing RagTokenForGeneration: ['rag.question_encoder.question_encoder.bert_model.pooler.dense.bias', 'rag.question_encoder.question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing RagTokenForGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RagTokenForGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RagTokenForGeneration were not initialized from the model checkpoint at facebook/rag-token-nq and are newly initialized: ['rag.generator.lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# the pipline will link the retriever (our database) 
# and reader (our chatbot) together
from haystack.pipelines import GenerativeQAPipeline
pipe = GenerativeQAPipeline(generator, retriever)

ra_pipe = GenerativeQAPipeline(ra_generator, retriever)

# %%
## QnA time ##

def quesetion_ans(question_text, pipe_line):
  res = pipe_line.run(query=question_text, params={"Retriever": {"top_k": 6}})
  answers = res["answers"]
  answer = answers[0]

  print(answer.answer)
  # 'Eddard'
  print(answer.score)
  # 0.9946763813495636
  print(answer.context)
  # 'She travels with her father, Eddard, to King\'s Landing when he is...'
  print(answer.offsets_in_context)
  # [Span(start=72, end=78)]
  print(answer.offsets_in_document)
  # [Span(start=147, end=153)]
  #print(answer.meta)
  print(answer.meta['doc_scores'])
  print(answer.meta['doc_metas'])
  # 'ba2a8e87ddd95e380bec55983ee7d55f'

  return answers

# %%
question_text = "what are the anz application logging standard, list in dot point"
ns = quesetion_ans(question_text, pipe)
# Out:
# The ANZ application logging standard is a set of standards that govern how data is stored in electronic storage devices. The standard is based on the idea that data should be stored in a format that is easy to read and easy to manipulate. For example, if you want to store data on a hard drive, you need to be able to read it, write it, and manipulate it in a way that can be easily read and manipulated. The ANZ standard is designed to make it easy for data to be stored and manipulated in a manner that makes it easy to understand what data is being stored.
# None
# None
# None
# None
# [0.6599020481483923, 0.6590974522316406, 0.6590627895815472, 0.6582378594671305, 0.6581166601685717, 0.6573036236613612]
# [{'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '286'}, {'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '922'}, {'name': '191_Gendry.txt', '_split_id': 0, 'vector_id': '1859'}, {'name': '12_Fire.txt', '_split_id': 1, 'vector_id': '335'}, {'name': '332_Sansa_Stark.txt', '_split_id': 0, 'vector_id': '2453'}, {'name': '69_The_Red_Woman.txt', '_split_id': 1, 'vector_id': '2103'}]

# %%
question_text = "what are the steps i need to do to follow anz application logging standard, list in dot point"

ns = quesetion_ans(question_text, ra_pipe)
# Out:
#  firefox
# None
# None
# None
# None
# [0.6640947623199716, 0.6626659421239466, 0.66222517486918, 0.658597782383978, 0.6576700650322412, 0.6572178278267227]
# [{'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '922'}, {'name': '12_Fire.txt', '_split_id': 1, 'vector_id': '335'}, {'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '286'}, {'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '1123'}, {'name': '378_A_Game_of_Thrones__board_game_.txt', '_split_id': 0, 'vector_id': '2421'}, {'name': '12_Fire.txt', '_split_id': 0, 'vector_id': '1210'}]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:2734: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   warnings.warn(

# %%
##################################################
## inserting new knowlege to the knowlege store ##
##################################################

def insert_doc(doc_content):
  dicts = [
      {
          'content': f"{doc_content}",
          'meta': {'name': f"{doc_content[0:100]}"}
      }
  ]

  document_store.write_documents(dicts)
  document_store.update_embeddings(retriever, update_existing_embeddings=False)

# %%
#new_doc = "Louis Liu is a capability area lead at ANZ bank"
new_doc = "Louis Liu is a capability area lead at ANZ bank"

# %%
insert_doc(new_doc)
# Out:
# Writing Documents:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:haystack.document_stores.faiss:Updating embeddings for 2358 docs...
# Updating Embedding:   0%|          | 0/2358 [00:00<?, ? docs/s]

# %%
# use OpenAI (GPT 3)

import openai
# get API key from top-right dropdown on OpenAI website
openai.api_key = "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"

# %%
def openai_quesetion_ans(prompt):
    # query text-davinci-003
    res = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        temperature=0,
        max_tokens=2000,
        top_p=1,
        frequency_penalty=0.5,
        presence_penalty=0,
        stop=None
    )
    return res['choices'][0]['text'].strip()

# %%
def create_context_prompt(query, context):
  limit = 3750
  # build our prompt with the retrieved contexts included
  prompt_start = (
      "Answer the question based on the context below.\n\n"+
      "Context:\n ''' "
  )
  prompt_end = (
      f"''' \n\nQuestion: {query}\nAnswer:"
  )
  contexts = context
  prompt_context = prompt_start + "\n\n---\n\n" + contexts + prompt_end
  #print(prompt_context)
  return prompt_context

# %%
# doc search function
from haystack.utils import print_documents
from haystack.pipelines import DocumentSearchPipeline
p_retrieval = DocumentSearchPipeline(retriever)
res = p_retrieval.run(query="who is louis liu", params={"Retriever": {"top_k": 2}})
print_documents(res, max_text_len=512)
# Out:
# Query: who is louis liu
#
# {   'content': '\n'
#                '==Early life==\n'
#                'Benioff was born David Friedman in New York City, to a Jewish '
#                'family who emigrated from Austria, Romania, Germany, Poland '
#                'and Russia. He is the son of Barbara (Benioff) and Stephen '
#                'Friedman, who is a former head of Goldman Sachs. He is a '
#                'distant cousin of Salesforce founder Marc Benioff. As an '
#                "adult, he uses the last name Benioff, his mother's maiden "
#                'name, to avoid confusion with other writers named David '
#                'Friedman. He is the youngest of three children (Suzy, '
#                'Caroline, and David) and grew up ...',
#     'name': '33_David_Benioff.txt'}
#
# {   'content': '\n'
#                '==Television adaptation==\n'
#                'Jason Momoa plays the role of Drogo in the television series.\n'
#                'Khal Drogo is played by Jason Momoa in the television '
#                'adaptation of the series of books. At his audition for the '
#                "part of Drogo he performed the ''Ka Mate'' haka. Momoa related "
#                'his experience in reading for the role:\n'
#                "When I read that ''Khal'' Drogo role, I was blown away. I "
#                "couldn't believe it was happening, I had to have that role. I "
#                'was like, "Nobody is going to take that role from me." ... '
#                "People say it's easy to play...",
#     'name': '501_Khal_Drogo.txt'}

# %%
def context_search(question_text):
  p_retrieval = DocumentSearchPipeline(retriever)
  res = p_retrieval.run(query=f"{question_text}", params={"Retriever": {"top_k": 3}})
  #print_documents(res, max_text_len=512, print_meta=True)
  context = [x.content for x in res['documents']]
  
  full_context = ""
  for x in context:
    full_context+= "\n\n" + x

  return full_context

# %%
question_text = "who is Louis Liu"

# %%
full_context = context_search(question_text)
context_question = create_context_prompt(question_text, full_context)
ns = openai_quesetion_ans(context_question)
print(ns)
# Out:
# • Ensure that every log line produced contains a timestamp with a time zone offset from UTC.
# • Ensure that the application logs a 128 bit traceID associated with a particular request flow.
# • Ensure that the application can receive and propagate a traceID from request headers.
# • Ensure log files are produced according to a defined schema.
# • Ensure the application can provide logs to a central log aggregator in a consistent, plain-text format.
# • Ensure that each log entry records the log level that generated that particular line (see Appendix A for suggested outputs at each level).
# • Ensure that all application logs are able to provide their application name and/or their executable.
# • Ensure that application logs do not contain sensitive data. The information produced in the log must be treated the same as the data within the system. If data is masked or treated as confidential internally, it should be treated similarly inside of logs as well. Additionally, any data which could be used to escalate privileges or gain access to systems should also be masked or obscured in logs.
# • Ensure applications have ability to allow for transition and modification of log levels/verbosity (i.e Warn to Debug, or Debug to Trace) on fly without any service degradation
# •Ensure all user management (UAM) activities are recorded at log level which generates during regular usage including login, privilege escalation/removal and time associated with activity
#  •Ensure all queries and requests for information within an app are logged and recorded at same level which generates during regular usage    •Ensure app has own repository of unique error codes corresponding to particular errors & suggested remediation processes    •Ensure there is central repository for error codes & remediation processes accessible by different teams with consistent terminology    •Application error codes must be unique across apps & managed centrally

# %%
ns = openai_quesetion_ans(question_text)
print(ns)
# Out:
# Louis Liu is a Chinese-American entrepreneur and investor. He is the founder and CEO of the venture capital firm, Lightspeed Venture Partners, which has invested in companies such as Snapchat, Affirm, and AppDynamics.

# %%
doc_dir = '/content/data/'
# Convert files to dicts
docs = convert_files_to_docs(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)

from haystack.nodes import PreProcessor
pre_processor = PreProcessor(
    clean_empty_lines=True,
    clean_whitespace=True,
    clean_header_footer=True,
    split_by="word",
    split_length=400,
    split_respect_sentence_boundary=True,
    split_overlap=0)
# Out:
# INFO:haystack.utils.preprocessing:Converting /content/data/test2 Application Logging Standard Ling.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/424_Night_King.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/86_Game_of_Thrones__season_4_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/10_Beyond_the_Wall__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/408_The_Last_of_the_Starks.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/369_Samwell_Tarly.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/334_Rickon_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/118_Dark_Wings__Dark_Words.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/444_Cripples__Bastards__and_Broken_Things.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/195_World_of_A_Song_of_Ice_and_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/514_Book_of_the_Stranger.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/330_Oberyn_Martell.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/73_A_Man_Without_Honor.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/474_Bronn__character_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/435_White_Walker.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/420_Blood_of_My_Blood.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/439_Melisandre.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/513_Oathbreaker__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/24_Game_of_Thrones__Season_1__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/512_Home__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/365_A_Song_of_Ice_and_Fire_Roleplaying.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/129_Second_Sons.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/136_Game_of_Thrones__Season_8__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/317_The_Broken_Man.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/450_Baelor.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/501_Khal_Drogo.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/343_Catelyn_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/75_Blackwater__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/1_Dragonstone__Game_of_Thrones_episode_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/482_Petyr_Baelish.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/218_Olenna_Tyrell.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/26_Game_of_Thrones__Season_3__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/56_First_of_His_Name.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/131_Mhysa.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/210_The_Mountain_and_the_Viper.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/12_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/80_A_Song_of_Ice_and_Fire_fandom.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/456_Works_based_on_A_Song_of_Ice_and_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/394_Game_of_Thrones__2014_video_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/447_You_Win_or_You_Die.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/27_Game_of_Thrones__Season_4__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/442_Game_of_Thrones__season_1_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/224_The_Night_Lands.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/74_The_Prince_of_Winterfell.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/356_Tales_of_Dunk_and_Egg.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/349_List_of_Game_of_Thrones_characters.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/102_The_Princess_and_the_Queen.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/400_Winterfell__Game_of_Thrones_episode_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/33_David_Benioff.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/28_Jorah_Mormont.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/452_Fire_and_Blood__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/211_The_Watchers_on_the_Wall.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/360_List_of_Game_of_Thrones_episodes.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/99_A_Song_of_Ass_and_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/87_Valar_Dohaeris.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/77_Game_of_Thrones_Ascent.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/78_The_Rains_of_Castamere.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/154_Margaery_Tyrell.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/39_Renly_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/311_Game_of_Thrones__season_7_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/504_List_of_A_Song_of_Ice_and_Fire_video_games.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/228_Souad_Faress.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/345_A_Game_of_Thrones__comics_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/194_A_Song_of_Ice_and_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/480_Varys.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/306_The_Dance_of_Dragons.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/98_Black_Friday__South_Park_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/515_The_Door__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/329_Robert_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/22_The_Rains_of_Castamere__song_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/331_Bran_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/9_Game_of_Thrones_Tapestry.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/495_Hodor.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/475_A_Game_of_Thrones__role-playing_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/37_Joffrey_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/460_Battle_of_the_Bastards.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/371_Cersei_Lannister.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/232_Tommen_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/8_Eastwatch.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/411_The_Iron_Throne__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/54_Two_Swords__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/332_Sansa_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/208_Robb_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/193_Lord_Snow.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/410_The_Bells__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/310_Mother_s_Mercy.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/20_Light_of_the_Seven.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/368_Jaime_Lannister.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/373_Tywin_Lannister.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/396_Game_of_Thrones__season_6_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/76_Valar_Morghulis.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/135_Game_of_Thrones__Season_7__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/445_The_Wolf_and_the_Lion.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/511_After_the_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/342_Theon_Greyjoy.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/21_The_Bear_and_the_Maiden_Fair__song_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/346_Ygritte.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/299_Rani_Mahal__TV_series_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/151_Ellaria_Sand.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/199_A_Storm_of_Swords.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/362_Winter_Is_Coming.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/79_Thronecast.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/146_The_Sons_of_the_Dragon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/160_Viserys_Targaryen.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/126_Kissed_by_Fire.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/23_Game_of_Thrones_Live_Concert_Experience.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/425_No_One__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/347_Game_of_Thrones__season_2_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/69_The_Red_Woman.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/55_Breaker_of_Chains.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/348_The_Winds_of_Winter.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/121_The_Bear_and_the_Maiden_Fair.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/53_The_Lion_and_the_Rose.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/212_The_Children__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/0_Game_of_Thrones__season_8_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/52_Catch_the_Throne.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/197_A_Game_of_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/214_Dothraki_language.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/7_The_Spoils_of_War__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/487_Ramsay_Bolton.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/273_High_Sparrow.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/3_The_Queen_s_Justice.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/304_Hardhome.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/201_A_Game_of_Thrones__card_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/198_A_Clash_of_Kings.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/217_The_Rogue_Prince.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/446_A_Golden_Crown.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/233_Myrcella_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/367_Gregor_Clegane.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/68_The_Gift__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/119_Walk_of_Punishment.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/449_The_Pointy_End.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/67_Unbowed__Unbent__Unbroken.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/407_The_Long_Night__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/485_Oathkeeper.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/461_The_Winds_of_Winter__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/97_Tyrion_Lannister.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/481_Sandor_Clegane.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/378_A_Game_of_Thrones__board_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/209_Mockingbird__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/101_Titties_and_Dragons.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/359_Kill_the_Boy.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/358_A_Game_of_Thrones__Genesis.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/127_The_Climb__Game_of_Thrones_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/148_Game_of_Thrones__Winter_Is_Coming.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/263_Tormund_Giantsbane.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/506_Game_of_Thrones_Theme.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/43_Arya_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/40_Stannis_Baratheon.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/401_Power_Is_Power.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/84_List_of_awards_and_nominations_received_by_Game_of_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/30_List_of_A_Song_of_Ice_and_Fire_characters.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/477_A_Dance_with_Dragons.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/85_Game_of_Thrones__Seven_Kingdoms.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/488_Brienne_of_Tarth.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/262_Gilly__character_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/191_Gendry.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/508_A_Game_of_Thrones__Second_Edition__card_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/379_Davos_Seaworth.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/25_Game_of_Thrones__Season_2__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/395_Game_of_Thrones__season_5_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/454_Music_of_Game_of_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/133_Game_of_Thrones__Season_5__soundtrack_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/213_Valyrian_languages.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/229_Game_of_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/57_The_Laws_of_Gods_and_Men.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/145_Elio_M._García_Jr._and_Linda_Antonsson.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/202_A_Feast_for_Crows.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/207_Jon_Snow__character_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/340_Roose_Bolton.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/403_Jenny_of_Oldstones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/11_The_Dragon_and_the_Wolf.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/120_And_Now_His_Watch_Is_Ended.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/341_Ned_Stark.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/2_Stormborn.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/44_Daenerys_Targaryen.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/130_Game_of_Thrones_title_sequence.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/453_Game_of_Thrones__2012_video_game_.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/399_For_the_Throne__Music_Inspired_by_the_HBO_Series_Game_of_Thrones.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/443_The_Kingsroad.txt
# INFO:haystack.utils.preprocessing:Converting /content/data/GOT/134_Game_of_Thrones__Season_6__soundtrack_.txt
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
docs = pre_processor.process(docs)
# Out:
# Preprocessing:   0%|          | 0/2498 [00:00<?, ?docs/s]
# WARNING:haystack.nodes.preprocessor.preprocessor:We found one or more sentences whose word count is higher than the split length.
# WARNING:haystack.nodes.preprocessor.preprocessor:Document 35790c79db1496b5d2c538ff868ca702 is 13596 characters long after preprocessing, where the maximum length should be 10000. Something might be wrong with the splitting, check the document affected to prevent issues at query time.

# %%
docs = pre_processor.process(docs)
# Now, let's write the dicts containing documents to our DB.
document_store.write_documents(docs)
document_store.update_embeddings(retriever)
# Out:
# Preprocessing:   0%|          | 0/2797 [00:00<?, ?docs/s]
# WARNING:haystack.nodes.preprocessor.preprocessor:Document 35790c79db1496b5d2c538ff868ca702 is 13596 characters long after preprocessing, where the maximum length should be 10000. Something might be wrong with the splitting, check the document affected to prevent issues at query time.
# Writing Documents:   0%|          | 0/2797 [00:00<?, ?it/s]
# INFO:haystack.document_stores.faiss:Updating embeddings for 3224 docs...
# Updating Embedding:   0%|          | 0/3224 [00:00<?, ? docs/s]
# Create embeddings:   0%|          | 0/3232 [00:00<?, ? Docs/s]

# %%
question_text = "what are the  Minimum, mandatory requirements in application logging standard, list in dot point"
full_context = context_search(question_text)
context_question = create_context_prompt(question_text, full_context)
ns = openai_quesetion_ans(context_question)
print(ns)
# Out:
# * Ensure that every log line produced contains a timestamp with a time zone offset from UTC.
# * Ensure that the application logs a 128 bit traceID associated with a particular request flow.
# * Ensure that the application can receive and propagate a traceID from request headers.
# * Distributed Tracing Pattern Headers
# * Ensure that log files are produced according to a defined schema.
# * Ensure the application can provide logs to a central log aggregator in a consistent, plain-text format.
# * Ensure that each log entry records the log level that generated that particular line (see Appendix A for suggested outputs at each level).
# * Ensure that all application logs are able to provide their application name and/or their executable.
# * Ensure that application logs do not contain sensitive data.

# %%
full_context
# Out:
# '\n\nANZ Application Logging Standard\nAn application log is a file of events that are logged by a software application. It contains errors, informational events and warnings. An application log may also be referred to as an application log file. The log file can reveal message flow issues and application problems. It can also contain information about user and system actions that have occurred. The format and content of an application log are determined by the developer of the software program, rather than the OS. Application logging is the act of keeping a log, recording events, in the simplest case messages are written to a single log file.\nApplication logging is important because:\n* Developers can use logs to assist with debugging applications during and after development.\n* Operators and system administrators can detect, understand, diagnose and report on the availability of critical applications and services.\n* Security teams can analyse logs to recognise and respond to security threats.\nThe purpose of this standard is to develop and maintain consistency across ANZ\'s applications in the data captured by the application logs. Previously, ANZ\'s applications have logged according to team or area defined requirements creating difficulties when processing logs across multiple systems, or following a transaction through multiple applications. This standard does not aim to be overly prescriptive in terms of format, but seeks to create a baseline set of logging requirements for all ANZ applications to build their logs upon, according to their own requirements.\nThis standard is intended to mitigate the following risks or obligations:\n* Possibilities include degraded customer experience, employees unable to perform their role and regulatory failures.\n* Regional regulatory trend towards requiring access and information from application logs (particularly HKMA and MAS), with possible additional regulators requiring this information in the future. This information particularly concerns data queries and UAM information.\n* Difficulty tracking transactions across different systems and disparities in information collected make it hard to identify and resolve issue, as well as to improve systems.\n* Inability to link together similar transactions end-to-end reduces the ability to determine impacts across systems of a particular intrusion or hack.\n* Legacy systems such as mainframe impose a risk because of the age of the technology; it is going to be difficult to implement a logging standard. Risk of exposure of private data and compromising the privacy policy.\n\nDetected non-compliances must be reported to the Standard Owner by the relevant Process Owner(s).\nThis standard has been split into maturity levels from level 1 through to level 4. Level 1 is the minimum and mandatory requirements that must be met by all applications within ANZ. Levels 2 to 4 articulate further logging capabilities that applications should strive to meet to improve supportability and robustness.\nIn order for an application to be designated as meeting a particular level of maturity, that application must meet all requirements within that level, as well as all the requirements in the levels preceding.\nLevel 1: Minimum, mandatory requirements\nEnsure that every log line produced contains a timestamp with a time zone offset from UTC.\nEnsure that the application logs a 128 bit traceID associated with a particular request flow.\nEnsure that the application can receive and propagate a traceID from request headers.\nDistributed Tracing Pattern Headers\nEnsure that log files are produced according to a defined schema.\nSome possible options through which a schema can be enforced outlined below:\n* Implied schema through consistent ordering\n* Structured format (JSON, XML)\nEnsure the application can provide logs to a central log aggregator in a consistent, plain-text format.\nEnsure that each log entry records the log level that generated that particular l ...

# %%
full_txt = """

Guides home 
Guide 1: Get started with Confluence 
A brief overview of Confluence 
Set up your site and spaces 
Create and collaborate on content 
Navigate Confluence 
Confluence best practices 
Create compelling contentStay organizedIncrease collaboration and engagement
Guide 2: Extend the functionality of Confluence 
Confluence integrations 
Using Confluence and Jira software together 
Using Confluence and Jira Service Management Together 
Confluence Use Cases 
Guide 3: Best practices for getting the most out of Confluence 
Guide 4: Knowledge management using Confluence 
Confluence best practices 
Teams love Confluence because it's flexible - it's easy to customize for any organization. To 
help you navigate the many powerful ways of using Confluence, we've curated a collection 
of best practices.
Before you dive in, sign up for your free Confluence Cloud site and read the following 
sections: set up your site and spaces, create content in Confluence, and navigate Confluence.
 
Create compelling content 
You work hard, and you want the content you create to reflect your efforts. These resources 
will help you create beautiful, compelling content that does just that.
Cloud
Create beautiful pages in Confluence 
In just under 4 mins, this video demonstrates how to create a page in Confluence from scratch 
or using best practice templates. The techniques you learn here will help you create beautiful 
Confluence pages that stand out from the crowd.
Watch video 
Cloud
Format your page 
Learn how to use the Confluence Cloud editor to apply formatting to text, change the page 
layout, and add tables, media, and links to your content.
Read tutorial 
Cloud
Start with a page template 
Confluence can be used for all kinds of work - meeting notes, project plans, onboarding 
guides, and beyond. Page templates kick-start your next project with industry expertise 
automatically infused.
Browse templates 
cloud / data center / server
Build your own custom template 
Page templates help you keep content consistent across your team or org. In this blog post, 
you'll learn how you can use the features of Confluence to make better templates.
Read blog 
 
Stay organized 
As your team grows and more people start using Confluence to share information, keeping 
things organized can become more of a challenge. Use these resources to create and maintain 
an effective organizational strategy for your team's content.
cloud / data center / server
Build an information architecture that scales 
Learn how to categorize your content with an information architecture based on your current 
and future organizational needs.
Read blog 
cloud / data center / server
Keep your site organized like Marie Kondo 
Follow these four steps to become the Marie Kondo of Confluence. This blog post will show 
you how to find a place for every page on your site, keep it organized, and get rid of content 
that no longer sparks joy.
Read blog 
cloud
Eliminate clutter by archiving old pages 
Learn how archiving old pages can help you keep your page tree neat, make it easier for 
people to find what they need, and give them confidence that the information they find is 
accurate and up to date.
Read article 
Cloud / data center / server
Excel in Confluence content management 
Learn how to guide end users to build their own easy-to-use, well-formatted content. This 
training will cover templates, page and space structure, and content management best 
practices.
Start training 
 
Increase collaboration and engagement 
Celebrate your wins, share in one another's challenges, and unite as a team behind shared 
goals. When your team feels they have a voice and a sense of ownership in your company's 
success, you'll be blown away by their passion, commitment, and productivity. These 
resources will help you increase employee engagement and foster better collaboration among 
team members.
cloud / data center / server
Create transparency at work 
Learn why transparency impacts organizational effectiveness and employee happiness. 
Leverage these strategies to make your culture more open, transparent, and collaborative.
Read blog 
cloud / data center / server
Increase employee engagement 
Learn what employee engagement is, why it's important, and how you can keep employees 
engaged and productive.
Read article 
cloud / data center / server
Use internal blogging to foster an open culture 
Learn how internal blogging can promote knowledge sharing, increase productivity, build 
employee bonds, and open up your workplace culture.
Read blog 
cloud
How to measure engagement with analytics 
Follow step-by-step instructions to analyze your Confluence instance, including number of 
views, most active readers and contributors, most active users, most popular spaces, and 
common searches.
Read tutorial 
Navigate Confluence 
Learn how to navigate Confluence Cloud so you can find the information you need quickly.
Read Part 4 
CONFLUENCE APPS AND INTEGRATIONS 
Learn how to integrate Confluence with your favorite business tools.
"""

# %%
insert_doc(full_txt)
# Out:
# Writing Documents:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:haystack.document_stores.faiss:Updating embeddings for 2360 docs...
# Updating Embedding:   0%|          | 0/2360 [00:00<?, ? docs/s]

# %%
question_text = "what can confluence do"

# %%
full_context = context_search(question_text)
context_question = create_context_prompt(question_text, full_context)
ns = openai_quesetion_ans(context_question)
print(ns)
# Out:
# Confluence is a collaboration software that can be used to create, share, and organize documents and other content. It can be used to create wikis, blogs, and other types of content.

# %%
full_context
# Out:
# '\n===Writing===\n"Two Swords" was written by executive producers David Benioff and D. B. Weiss, based on George R. R. Martin\'s original work from his novel \'\'A Clash of Kings\'\', chapters Sansa II and Sansa VIII, and \'\'A Storm of Swords\'\', chapters Jaime VII, Tyrion V, Tyrion IV, Jon VI, Jon IX, Daenerys V, and Arya XIII. Arya\'s revenge against Lommy\'s murderer using the same method of killing was depicted in \'\'The Winds of Winter\'\' chapter Mercy.The \'\'\'Dothraki language\'\'\' is a constructed fictional language in George R. R. Martin\'s fantasy novel series \'\'A Song of Ice and Fire\'\' and its television adaptation \'\'Game of Thrones\'\'. It is spoken by the Dothraki, a nomadic people in the series\'s fictional world. The language was developed for the TV series by the linguist David J. Peterson, working off the Dothraki words and phrases in Martin\'s novels.\n, the language comprised 3163 words, not all of which have been made public. In 2012, 146 newborn girls in the United States were named "Khaleesi", the Dothraki term for the wife of a \'\'khal\'\' or ruler, and the title adopted in the series by Daenerys Targaryen. Dothraki and Valyrian have been described as "the most convincing fictional tongues since Elvish".\'\'Game of Thrones\'\' is an American fantasy drama television series created by David Benioff and D. B. Weiss. The series is based on George R. R. Martin\'s series of fantasy novels, \'\'A Song of Ice and Fire\'\'. The series takes place on the fictional continents of Westeros and Essos, and chronicles the power struggles among noble families as they fight for control of the Iron Throne of the Seven Kingdoms. The series starts when House Stark, led by Lord Eddard "Ned" Stark (Sean Bean), is drawn into schemes surrounding King Robert Baratheon (Mark Addy).\nThe series premiered on April 17, 2011, on HBO. David Benioff and D. B. Weiss both serve as executive producers, along with Carolyn Strauss, Frank Doelger, Bernadette Caulfield, and George R. R. Martin. Filming for the series has taken place in a number of locations, including Croatia, Ireland, Iceland, and Spain. Episodes were broadcast on Sunday at 9:00 pm Eastern Time, and the episodes are between 50 and 82 minutes in length. The first seven seasons are available on DVD and Blu-ray.\nThe series concluded with its eighth season, which premiered on April 14, 2019, and consisted of six episodes. The show\'s episodes have won numerous awards including four Primetime Emmy Award for Outstanding Drama Series. '
